# %% [markdown]
# # Job Listings Data Cleaning

# %% [markdown]
# This notebook takes a dataset of joblistings and cleans it into a more usable format.
#
#  - Duplicates are removed, keywords from the job title are extracted
#  - The salary estimate range is split into min and max columns with numerical type
#  - Anomalies are removed
#  - The size and revenue ranges are converted approximante values in numerical type
#  - Other null or problematic values are dealt with

# %%
import pandas as pd
import numpy as np
import re

# %%
# import the dataset and look at the first few rows

df = pd.read_csv(r"C:/Users/mattc/OneDrive/Documents/Data/Python/DS Job Listings.csv")
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9   New York, NY            New York, NY
#
#                       Size  Founded        Type of ownership  \
# 0   1001 to 5000 employees     1993   Nonprofit Organization
# 1  5001 to 10000 employees     1968         Company - Public
# 2   1001 to 5000 employees     1981  Private Practice / Firm
# 3    501 to 1000 employees     2000         Company - Public
# 4      51 to 200 employees     1998        Company - Private
#
#                                 Industry             Sector  \
# 0                     Insurance Carriers          Insurance
# 1                 Research & Development  Business Services
# 2                             Consulting  Business Services
# 3  Electrical & Electronic Manufacturing      Manufacturing
# 4                Advertising & Marketing  Business Services
#
#                       Revenue  \
# 0    Unknown / Non-Applicable
# 1      $1 to $2 billion (USD)
# 2  $100 to $500 million (USD)
# 3  $100 to $500 million (USD)
# 4    Unknown / Non-Applicable
#
#                                          Competitors
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee

# %% [markdown]
# ## Look for and remove any duplicates

# %%
duplicates = df[df.duplicated(keep=False)]
duplicates
# Out:
#                      Job Title level_keywords               role_keywords  \
# 131       Senior Data Engineer         senior              data, engineer
# 134  Machine Learning Engineer           None  machine learning, engineer
# 135  Machine Learning Engineer           None  machine learning, engineer
# 136       Senior Data Engineer         senior              data, engineer
# 357             Data Scientist           None             data, scientist
# 358             Data Scientist           None             data, scientist
# 359             Data Scientist           None             data, scientist
# 360             Data Scientist           None             data, scientist
# 361             Data Scientist           None             data, scientist
# 362             Data Scientist           None             data, scientist
# 388             Data Scientist           None             data, scientist
# 389             Data Scientist           None             data, scientist
# 495             Data Scientist           None             data, scientist
# 496             Data Scientist           None             data, scientist
# 497             Data Scientist           None             data, scientist
# 498             Data Scientist           None             data, scientist
# 499             Data Scientist           None             data, scientist
# 500             Data Scientist           None             data, scientist
#
#                   Salary Estimate  min_salary_est($K)  max_salary_est($K)  \
# 131   $90K-$109K (Glassdoor est.)                  90                 109
# 134   $90K-$109K (Glassdoor est.)                  90                 109
# 135   $90K-$109K (Glassdoor est.)                  90                 109
# 136   $90K-$109K (Glassdoor est.)                  90                 109
# 357  $122K-$146K (Glassdoor est.)                 122                 146
# 358  $122K-$146K (Glassdoor est.)                 122                 146
# 359  $122K-$146K (Glassdoor est.)                 122                 146
# 360  $122K-$146K (Glassdoor est.)                 122                 146
# 361  $122K-$146K (Glassdoor est.)                 122                 146
# 362  $122K-$146K (Glassdoor est.)                 122                 146
# 388  $110K-$163K (Glassdoor est.)                 110                 163
# 389  $110K-$163K (Glassdoor est.)                 110                 163
# 495   $95K-$119K (Glassdoor est.)                  95                 119
# 496   $95K-$119K (Glassdoor est.)                  95                 119
# 497   $95K-$119K (Glassdoor est.)                  95                 119
# 498   $95K-$119K (Glassdoor est.)                  95                 119
# 499   $95K-$119K (Glassdoor est.)                  95                 119
# 500   $95K-$119K (Glassdoor est.)                  95                 119
#
#                                        Job Description  Rating  \
# 131  Lendio is looking to fill a position for a Sen...     4.9
# 134  Role Description\nTriplebyte screens and evalu...     3.2
# 135  Role Description\nTriplebyte screens and evalu...     3.2
# 136  Lendio is looking to fill a position for a Sen...     4.9
# 357  Job Overview: The Data Scientist is a key memb...     NaN
# 358  Job Overview: The Data Scientist is a key memb...     NaN
# 359  Job Overview: The Data Scientist is a key memb...     NaN
# 360  Job Overview: The Data Scientist is a key memb...     NaN
# 361  Job Overview: The Data Scientist is a key memb...     NaN
# 362  Job Overview: The Data Scientist is a key memb...     NaN
# 388  Job Description\nAs a Data Scientist, you will...     NaN
# 389  Job Description\nAs a Data Scientist, you will...     NaN
# 495  Job Overview: The Data Scientist is a key memb...     NaN
# 496  Job Overview: The Data Scientist is a key memb...     NaN
# 497  Job Overview: The Data Scientist is a key memb...     NaN
# 498  Job Overview: The Data Scientist is a key memb...     NaN
# 499  Job Overview: The Data Scientist is a key memb...     NaN
# 500  Job Overview: The Data Scientist is a key memb...     NaN
#
#         Company Name           Location       Headquarters  \
# 131      Lendio\n4.9           Lehi, UT           Lehi, UT
# 134  Triplebyte\n3.2             Remote  San Francisco, CA
# 135  Triplebyte\n3.2             Remote  San Francisco, CA
# 136      Lendio\n4.9           Lehi, UT           Lehi, UT
# 357   Hatch Data Inc  San Francisco, CA
# 358   Hatch Data Inc  San Francisco, CA
# 359   Hatch Data Inc  San Francisco, CA
# 360   Hatch Data Inc  San Francisco, CA
# 361   Hatch Data Inc  San Francisco, CA
# 362   Hatch Data Inc  San Francisco, CA
# 388           HireAi  San Francisco, CA
# 389           HireAi  San Francisco, CA
# 495   Hatch Data Inc  San Francisco, CA
# 496   Hatch Data Inc  San Francisco, CA
# 497   Hatch Data Inc  San Francisco, CA
# 498   Hatch Data Inc  San Francisco, CA
# 499   Hatch Data Inc  San Francisco, CA
# 500   Hatch Data Inc  San Francisco, CA
#
#                      Size  approx_employees  Founded  Type of ownership  \
# 131  201 to 500 employees               350     2011  Company - Private
# 134   51 to 200 employees               125     2015  Company - Private
# 135   51 to 200 employees               125     2015  Company - Private
# 136  201 to 500 employees               350     2011  Company - Private
# 357                                    <NA>       -1
# 358                                    <NA>       -1
# 359                                    <NA>       -1
# 360                                    <NA>       -1
# 361                                    <NA>       -1
# 362                                    <NA>       -1
# 388                                    <NA>       -1
# 389                                    <NA>       -1
# 495                                    <NA>       -1
# 496                                    <NA>       -1
# 497                                    <NA>       -1
# 498                                    <NA>       -1
# 499                                    <NA>       -1
# 500                                    <NA>       -1
#
#                          Industry                  Sector  \
# 131                       Lending                 Finance
# 134  Computer Hardware & Software  Information Technology
# 135  Computer Hardware & Software  Information Technology
# 136                       Lending                 Finance
# 357
# 358
# 359
# 360
# 361
# 362
# 388
# 389
# 495
# 496
# 497
# 498
# 499
# 500
#
#                        Revenue  approx_revenue($Mil) Competitors
# 131  $50 to $100 million (USD)                  75.0
# 134   Unknown / Non-Applicable                  <NA>
# 135   Unknown / Non-Applicable                  <NA>
# 136  $50 to $100 million (USD)                  75.0
# 357                                             <NA>
# 358                                             <NA>
# 359                                             <NA>
# 360                                             <NA>
# 361                                             <NA>
# 362                                             <NA>
# 388                                             <NA>
# 389                                             <NA>
# 495                                             <NA>
# 496                                             <NA>
# 497                                             <NA>
# 498                                             <NA>
# 499                                             <NA>
# 500                                             <NA>

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Identifying keywords in the job titles

# %%
len(df['Job Title'].unique())              #number of different job titles in the table
# Out:
# 172

# %%
# displays all unique job titles to scan for common keywords

df['Job Title'].unique()
# Out:
# array(['Sr Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert',
#        'Staff Data Scientist - Analytics',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Experienced Data Scientist', 'Data Scientist - Contract',
#        'Data Analyst II', 'Medical Lab Scientist',
#        'Data Scientist/Machine Learning', 'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights',
#        'Data Scientist - Risk', 'Data Scientist-Human Resources',
#        'Senior Research Statistician- Data Scientist', 'Data Engineer',
#        'Associate Data Scientist', 'Business Intelligence Analyst',
#        'Senior Analyst/Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst I',
#        'Scientist - Molecular Biology',
#        'Computational Scientist, Machine Learning',
#        'Senior Data Scientist', 'Jr. Data Engineer',
#        'E-Commerce Data Analyst', 'Data Analytics Engineer',
#        'Product Data Scientist - Ads Data Science',
#        'Data Scientist - Intermediate', 'Global Data Analyst',
#        'Data & Machine Learning Scientist',
#        'Data Scientist - Machine Learning', 'Data Engineer (Remote)',
#        'Data Scientist, Applied Machine Learning - Bay Area',
#        'Principal Data Scientist', 'Business Data Analyst',
#        'Purification Scientist', 'Data Engineer, Enterprise Analytics',
#        'Data Scientist 3 (718)', 'Real World Science, Data Scientist',
#        'Data Scientist - Image and Video Analytics',
#        'Data Science Manager, Payment Acceptance - USA',
#        'Data Scientist / Applied Mathematician',
#        'Patient Safety- Associate Data Scientist',
#        '(Sr.) Data Scientist -', 'Data Scientist, Kinship - NYC/Portland',
#        'Applied Technology Researcher / Data Scientist',
#        'Health Data Scientist - Biomedical/Biostats',
#        'Staff Data Scientist', 'Sr Data Engineer (Sr BI Developer)',
#        'Lead Data Scientist', 'RFP Data Analyst',
#        'Data Scientist (TS/SCI)', 'Software Engineer - Data Science',
#        'Data Analyst/Engineer', 'NGS Scientist', 'Senior Data Engineer',
#        'Sr. ML/Data Scientist - AI/NLP/Chatbot',
#        'Data Integration and Modeling Engineer',
#        'Tableau Data Engineer 20-0117', 'AI Data Scientist',
#        'Research Scientist Patient Preferences (Remote)',
#        'Scientist - Biomarker and Flow Cytometry', 'Analytics Manager',
#        'Staff Scientist- Upstream PD',
#        'Sr Scientist - Extractables & Leachables',
#        'ELISA RESEARCH SCIENTIST (CV-15)', 'Say Business Data Analyst',
#        'Geospatial Data Scientist', 'Computational Scientist',
#        'Senior Data Analyst', 'Sr Data Analyst',
#        'Machine Learning Scientist - Bay Area, CA',
#        'Senior Data Scientist - Algorithms',
#        'Senior Data & Machine Learning Scientist',
#        'Research Scientist - Patient-Centered Research (Remote)',
#        'Jr. Business Data Analyst (position added 6/12/2020)',
#        'Sr. Data Scientist II',
#        'Production Engineer - Statistics/Data Analysis',
#        'Statistical Scientist', 'Computational Behavioral Scientist',
#        'Principal Data Scientist - Machine Learning',
#        'Principal Machine Learning Scientist',
#        'Senior Data Scientist - R&D Oncology',
#        'Health Plan Data Analyst, Sr',
#        'Principal Scientist/Associate Director, Quality Control and Analytical Technologies',
#        'Analytics - Business Assurance Data Analyst',
#        'Senior Data Scientist – Image Analytics, Novartis AI Innovation Lab',
#        'Data Science Instructor', 'Senior Business Intelligence Analyst',
#        'In-Line Inspection Data Analyst',
#        'Data Scientist - TS/SCI FSP or CI Required',
#        'Data Scientist - TS/SCI Required',
#        'Data Science Software Engineer',
#        'ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING - SAN ANTONIO OR',
#        'AI Ops Data Scientist', 'Intelligence Data Analyst, Senior',
#        'Analytics Manager - Data Mart',
#        'Data Modeler (Analytical Systems)',
#        'Senior Machine Learning Scientist - Bay Area, CA',
#        'Report Writer-Data Analyst', 'Staff Data Scientist - Pricing',
#        'Equity Data Insights Analyst - Quantitative Analyst',
#        'Operations Data Analyst', 'Software Data Engineer',
#        'Real World Evidence (RWE) Scientist', 'Computer Scientist 1',
#        'Environmental Data Science', 'Staff BI and Data Engineer',
#        'Data Scientist - Statistics, Mid-Career',
#        'Director of Data Science',
#        'Data Engineer, Digital & Comp Pathology',
#        'Manager / Lead, Data Science & Analytics',
#        'Diversity and Inclusion Data Analyst',
#        'Data Scientist Machine Learning', 'Chief Scientist',
#        'Development Scientist, Voltaren',
#        'Principal Data & Analytics Platform Engineer',
#        'Machine Learning Engineer/Scientist',
#        'Data Analyst - Unilever Prestige', 'VP, Data Science',
#        'Data Engineer - Kafka', 'Decision Scientist',
#        'Data Science All Star Program - Data Engineer Track',
#        'Scientist - Machine Learning', 'Sr. Data Scientist',
#        'Applied AI Scientist / Engineer',
#        'Data Engineer (Analytics, SQL, Python, AWS)',
#        'Senior Data Analyst - Finance & Platform Analytics',
#        'Market Research Data Scientist',
#        'IT Partner Digital Health Technology and Data Science',
#        'Software Engineer (Data Scientist, C,C++,Linux,Unix) - SISW - MG',
#        'Senior Clinical Data Scientist Programmer',
#        'Computer Vision / Deep Learning Scientist',
#        'Data Solutions Engineer - Data Modeler',
#        'Data Scientist (TS/SCI w/ Poly)',
#        'Weapons and Sensors Engineer/Scientist',
#        'Applied Computer Scientist', 'Cloud Data Engineer (Azure)',
#        'Lead Certified Clinical Laboratory Scientist - Saturday - Tuesday, 8:00pm - 6:30am shift',
#        'Sr. Data Analyst',
#        'Senior Scientist - Toxicologist - Product Integrity (Stewardship)',
#        'Senior Machine Learning Engineer',
#        'Data Scientist- Industrial Discrete Sector Industry',
#        'Senior Principal Data Scientist (Python/R)',
#        'Data Scientist(s)/Machine Learning Engineer',
#        'Scientist / Group Lead, Cancer Biology',
#        'Manager, Field Application Scientist, Southeast',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING',
#        'Machine Learning Scientist / Engineer', 'Data Science Analyst',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - TRANSPORTATION TECHNOLOGY',
#        'Software Engineer - Machine Learning & Data Science (Applied Intelligence Services Team)',
#        'Clinical Data Analyst', 'Data Scientist Technical Specialist',
#        'Data Science Manager', 'Big Data Engineer', 'Data Architect',
#        'Aviation AI/ML Data Scientist', 'Machine Learning Engineer, Sr.',
#        'Information Systems Engineering Specialist (Engineering Scientist)',
#        'Scientist/Research Associate-Metabolic Engineering',
#        'Vice President, Biometrics and Clinical Data Management',
#        'Enterprise Data Analyst (Enterprise Portfolio Management Office)',
#        'Lead Data Scientist – Network Analysis and Control',
#        'Sr. Research Associate/ Scientist, NGS prep & Molecular Genomics',
#        'Developer III - Data Science',
#        'Hydrogen/Tritium Materials Scientist (Experienced)',
#        'Data Scientist/Data Analytics Practitioner',
#        'AI/ML - Machine Learning Scientist, Siri Understanding'],
#       dtype=object)

# %%
# list of keywords relating to the level of the job

level_keywords = ['sr', 'senior', 'jr', 'junior', 'experienced', 'staff', 'principal', 'lead', 'manager', 'chief', 'graduate', 'vice', 'president', 'expert']

# list of keywords relating to the role of the job

role_keywords = ['software', 'data', 'business', 'computer', 'computational', 'risk', 'scientist', 'science', 'machine learning', 'ml', 'ai', 'analyst', 'analytics', 'engineer', 'engineering', 'programmer', 'programming', 'developer']

# %%
# finds any of the job level keywords in the job title

def extract_level_keywords(title):
    found_keywords = [kw for kw in level_keywords if re.search(rf'\b{kw}\b', title, re.IGNORECASE)]
    return ', '.join(found_keywords) if found_keywords else None

# %%
# finds any of the job role keywords in the job title

def extract_role_keywords(title):
    found_keywords = [kw for kw in role_keywords if re.search(rf'\b{kw}\b', title, re.IGNORECASE)]
    return ', '.join(found_keywords) if found_keywords else None

# %%
# applies the above functions to the job title column and creates new columns with the keywords in

df['level_keywords'] = df['Job Title'].apply(extract_level_keywords)
df['role_keywords'] = df['Job Title'].apply(extract_role_keywords)

#reorders columns to put keywords next to job title

df = df[['Job Title', 'level_keywords', 'role_keywords', 'Salary Estimate', 'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors']]
df.head()
# Out:
#            Job Title level_keywords    role_keywords  \
# 0  Sr Data Scientist             sr  data, scientist
# 1     Data Scientist           None  data, scientist
# 2     Data Scientist           None  data, scientist
# 3     Data Scientist           None  data, scientist
# 4     Data Scientist           None  data, scientist
#
#                 Salary Estimate  \
# 0  $137K-$171K (Glassdoor est.)
# 1  $137K-$171K (Glassdoor est.)
# 2  $137K-$171K (Glassdoor est.)
# 3  $137K-$171K (Glassdoor est.)
# 4  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9   New York, NY            New York, NY
#
#                       Size  Founded        Type of ownership  \
# 0   1001 to 5000 employees     1993   Nonprofit Organization
# 1  5001 to 10000 employees     1968         Company - Public
# 2   1001 to 5000 employees     1981  Private Practice / Firm
# 3    501 to 1000 employees     2000         Company - Public
# 4      51 to 200 employees     1998        Company - Private
#
#                                 Industry             Sector  \
# 0                     Insurance Carriers          Insurance
# 1                 Research & Development  Business Services
# 2                             Consulting  Business Services
# 3  Electrical & Electronic Manufacturing      Manufacturing
# 4                Advertising & Marketing  Business Services
#
#                       Revenue  \
# 0    Unknown / Non-Applicable
# 1      $1 to $2 billion (USD)
# 2  $100 to $500 million (USD)
# 3  $100 to $500 million (USD)
# 4    Unknown / Non-Applicable
#
#                                          Competitors
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee

# %% [markdown]
# ## Separating salary estimate range into min and max

# %%
# taking the first number in the salary estimate column

min = df['Salary Estimate'].str.split('-').str[0]
df['min_salary_est($K)'] = min.str.replace(r'[^\d]', '', regex=True).astype(int)

# taking the second number in the salary estimate column

max = df['Salary Estimate'].str.split('-').str[1]
df['max_salary_est($K)'] = max.str.replace(r'[^\d]', '', regex=True).astype(int)

# reordering the columns to put the min and max salary estimate next to the salary estimate range

df = df[['Job Title', 'level_keywords', 'role_keywords', 'Salary Estimate', 'min_salary_est($K)', 'max_salary_est($K)', 'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors']]
df.head()
# Out:
#            Job Title level_keywords    role_keywords  \
# 0  Sr Data Scientist             sr  data, scientist
# 1     Data Scientist           None  data, scientist
# 2     Data Scientist           None  data, scientist
# 3     Data Scientist           None  data, scientist
# 4     Data Scientist           None  data, scientist
#
#                 Salary Estimate  min_salary_est($K)  max_salary_est($K)  \
# 0  $137K-$171K (Glassdoor est.)                 137                 171
# 1  $137K-$171K (Glassdoor est.)                 137                 171
# 2  $137K-$171K (Glassdoor est.)                 137                 171
# 3  $137K-$171K (Glassdoor est.)                 137                 171
# 4  $137K-$171K (Glassdoor est.)                 137                 171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9   New York, NY            New York, NY
#
#                       Size  Founded        Type of ownership  \
# 0   1001 to 5000 employees     1993   Nonprofit Organization
# 1  5001 to 10000 employees     1968         Company - Public
# 2   1001 to 5000 employees     1981  Private Practice / Firm
# 3    501 to 1000 employees     2000         Company - Public
# 4      51 to 200 employees     1998        Company - Private
#
#                                 Industry             Sector  \
# 0                     Insurance Carriers          Insurance
# 1                 Research & Development  Business Services
# 2                             Consulting  Business Services
# 3  Electrical & Electronic Manufacturing      Manufacturing
# 4                Advertising & Marketing  Business Services
#
#                       Revenue  \
# 0    Unknown / Non-Applicable
# 1      $1 to $2 billion (USD)
# 2  $100 to $500 million (USD)
# 3  $100 to $500 million (USD)
# 4    Unknown / Non-Applicable
#
#                                          Competitors
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1
# 2
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee

# %% [markdown]
# ## Checking the ratings for anomalies

# %%
df['Rating'].max()
# Out:
# 5.0

# %%
df['Rating'].min()
# Out:
# -1.0

# %%
# the ratings should not be negative so now searching for any negative ratings

for i in range(len(df['Rating'])):
    if df['Rating'][i] < 0:
        print(df.index[i], df['Rating'][i])
# Out:
# 154 -1.0
# 158 -1.0
# 230 -1.0
# 282 -1.0
# 285 -1.0
# 290 -1.0
# 319 -1.0
# 322 -1.0
# 329 -1.0
# 338 -1.0
# 351 -1.0
# 357 -1.0
# 358 -1.0
# 359 -1.0
# 360 -1.0
# 361 -1.0
# 362 -1.0
# 388 -1.0
# 389 -1.0
# 409 -1.0
# 411 -1.0
# 425 -1.0
# 430 -1.0
# 431 -1.0
# 437 -1.0
# 438 -1.0
# 440 -1.0
# 457 -1.0
# 459 -1.0
# 495 -1.0
# 496 -1.0
# 497 -1.0
# 498 -1.0
# 499 -1.0
# 500 -1.0
# 504 -1.0
# 519 -1.0
# 524 -1.0
# 555 -1.0
# 568 -1.0
# 613 -1.0
# 615 -1.0
# 637 -1.0
# 650 -1.0
# 656 -1.0
# 657 -1.0
# 660 -1.0
# 664 -1.0
# 668 -1.0
# 669 -1.0

# %%
# there are a number of ratings at -1.0, these full rows are all displayed below

negatives = []

for i in range(len(df['Rating'])):
    if df['Rating'][i] < 0:
        negatives.append(df.index[i])

df.loc[negatives]
# Out:
#                                   Job Title level_keywords  \
# 154        ELISA RESEARCH SCIENTIST (CV-15)           None
# 158               Machine Learning Engineer           None
# 230                          Data Scientist           None
# 282                          Data Scientist           None
# 285                          Data Scientist           None
# 290                          Data Scientist           None
# 319                          Data Scientist           None
# 322                          Data Scientist           None
# 329                          Data Scientist           None
# 338                          Data Scientist           None
# 351                          Data Scientist           None
# 357                          Data Scientist           None
# 358                          Data Scientist           None
# 359                          Data Scientist           None
# 360                          Data Scientist           None
# 361                          Data Scientist           None
# 362                          Data Scientist           None
# 388                          Data Scientist           None
# 389                          Data Scientist           None
# 409                          Data Scientist           None
# 411                          Data Scientist           None
# 425                          Data Scientist           None
# 430                          Data Scientist           None
# 431                          Data Scientist           None
# 437                          Data Scientist           None
# 438                          Data Scientist           None
# 440                          Data Scientist           None
# 457                          Data Scientist           None
# 459                          Data Scientist           None
# 495                          Data Scientist           None
# 496                          Data Scientist           None
# 497                          Data Scientist           None
# 498                          Data Scientist           None
# 499                          Data Scientist           None
# 500                          Data Scientist           None
# 504                          Data Scientist           None
# 519  Scientist / Group Lead, Cancer Biology           lead
# 524                          Data Scientist           None
# 555                          Data Scientist           None
# 568                          Data Scientist           None
# 613                          Data Scientist           None
# 615                          Data Scientist           None
# 637                          Data Scientist           None
# 650  Scientist / Group Lead, Cancer Biology           lead
# 656                          Data Scientist           None
# 657                          Data Scientist           None
# 660                          Data Scientist           None
# 664                          Data Scientist           None
# 668                          Data Scientist           None
# 669                          Data Scientist           None
#
#                   role_keywords               Salary Estimate  \
# 154                   scientist   $90K-$109K (Glassdoor est.)
# 158  machine learning, engineer  $101K-$165K (Glassdoor est.)
# 230             data, scientist   $71K-$123K (Glassdoor est.)
# 282             data, scientist   $91K-$150K (Glassdoor est.)
# 285             data, scientist  $141K-$225K (Glassdoor est.)
# 290             data, scientist  $141K-$225K (Glassdoor est.)
# 319             data, scientist    $145K-$225K(Employer est.)
# 322             data, scientist    $145K-$225K(Employer est.)
# 329             data, scientist   $79K-$147K (Glassdoor est.)
# 338             data, scientist   $79K-$147K (Glassdoor est.)
# 351             data, scientist  $122K-$146K (Glassdoor est.)
# 357             data, scientist  $122K-$146K (Glassdoor est.)
# 358             data, scientist  $122K-$146K (Glassdoor est.)
# 359             data, scientist  $122K-$146K (Glassdoor est.)
# 360             data, scientist  $122K-$146K (Glassdoor est.)
# 361             data, scientist  $122K-$146K (Glassdoor est.)
# 362             data, scientist  $122K-$146K (Glassdoor est.)
# 388             data, scientist  $110K-$163K (Glassdoor est.)
# 389             data, scientist  $110K-$163K (Glassdoor est.)
# 409             data, scientist  $124K-$198K (Glassdoor est.)
# 411             data, scientist  $124K-$198K (Glassdoor est.)
# 425             data, scientist  $124K-$198K (Glassdoor est.)
# 430             data, scientist   $79K-$133K (Glassdoor est.)
# 431             data, scientist   $79K-$133K (Glassdoor est.)
# 437             data, scientist   $79K-$133K (Glassdoor est.)
# 438             data, scientist   $79K-$133K (Glassdoor est.)
# 440             data, scientist   $79K-$133K (Glassdoor est.)
# 457             data, scientist   $69K-$116K (Glassdoor est.)
# 459             data, scientist   $69K-$116K (Glassdoor est.)
# 495             data, scientist   $95K-$119K (Glassdoor est.)
# 496             data, scientist   $95K-$119K (Glassdoor est.)
# 497             data, scientist   $95K-$119K (Glassdoor est.)
# 498             data, scientist   $95K-$119K (Glassdoor est.)
# 499             data, scientist   $95K-$119K (Glassdoor est.)
# 500             data, scientist   $95K-$119K (Glassdoor est.)
# 504             data, scientist   $95K-$119K (Glassdoor est.)
# 519                   scientist  $212K-$331K (Glassdoor est.)
# 524             data, scientist  $212K-$331K (Glassdoor est.)
# 555             data, scientist  $128K-$201K (Glassdoor est.)
# 568             data, scientist  $128K-$201K (Glassdoor est.)
# 613             data, scientist   $87K-$141K (Glassdoor est.)
# 615             data, scientist   $87K-$141K (Glassdoor est.)
# 637             data, scientist   $92K-$155K (Glassdoor est.)
# 650                   scientist   $92K-$155K (Glassdoor est.)
# 656             data, scientist  $105K-$167K (Glassdoor est.)
# 657             data, scientist  $105K-$167K (Glassdoor est.)
# 660             data, scientist  $105K-$167K (Glassdoor est.)
# 664             data, scientist  $105K-$167K (Glassdoor est.)
# 668             data, scientist  $105K-$167K (Glassdoor est.)
# 669             data, scientist  $105K-$167K (Glassdoor est.)
#
#      min_salary_est($K)  max_salary_est($K)  \
# 154                  90                 109
# 158                 101                 165
# 230                  71                 123
# 282                  91                 150
# 285                 141                 225
# 290                 141                 225
# 319                 145                 225
# 322                 145                 225
# 329                  79                 147
# 338                  79                 147
# 351                 122                 146
# 357                 122                 146
# 358                 122                 146
# 359                 122                 146
# 360                 122                 146
# 361                 122                 146
# 362                 122                 146
# 388                 110                 163
# 389                 110                 163
# 409                 124                 198
# 411                 124                 198
# 425                 124                 198
# 430                  79                 133
# 431                  79                 133
# 437                  79                 133
# 438                  79                 133
# 440                  79                 133
# 457                  69                 116
# 459                  69                 116
# 495                  95                 119
# 496                  95                 119
# 497                  95                 119
# 498                  95                 119
# 499                  95                 119
# 500                  95                 119
# 504                  95                 119
# 519                 212                 331
# 524                 212                 331
# 555                 128                 201
# 568                 128                 201
# 613                  87                 141
# 615                  87                 141
# 637                  92                 155
# 650                  92                 155
# 656                 105                 167
# 657                 105                 167
# 660                 105                 167
# 664                 105                 167
# 668                 105                 167
# 669                 105                 167
#
#                                        Job Description  Rating  \
# 154  Covaxx, a subsidiary of the UBI Group, has joi...    -1.0
# 158  Overview\n\nRadical Convergence is a fast-pace...    -1.0
# 230  Senior Data Scientist Active Secret clearance ...    -1.0
# 282  Greetings from Trovetechs!!!\n\nÂ\n\nWe have a...    -1.0
# 285  Greetings from Trovetechs!!!\n\nÂ\n\nWe have a...    -1.0
# 290  Work Authorization Those authorized to work in...    -1.0
# 319  Job Description\nSelecting features, building ...    -1.0
# 322  Job Description\nData Scientist\nAre you inter...    -1.0
# 329  Description:\n\nPosition Requires a Top Secret...    -1.0
# 338  Work in a fast growing startup with unlimited ...    -1.0
# 351  About Our AI/ML Team\n\nOur mission is to buil...    -1.0
# 357  Job Overview: The Data Scientist is a key memb...    -1.0
# 358  Job Overview: The Data Scientist is a key memb...    -1.0
# 359  Job Overview: The Data Scientist is a key memb...    -1.0
# 360  Job Overview: The Data Scientist is a key memb...    -1.0
# 361  Job Overview: The Data Scientist is a key memb...    -1.0
# 362  Job Overview: The Data Scientist is a key memb...    -1.0
# 388  Job Description\nAs a Data Scientist, you will...    -1.0
# 389  Job Description\nAs a Data Scientist, you will...    -1.0
# 409  About Navio:\nNavio builds software tools that...    -1.0
# 411  Our entertainment company is seeking a Data Sc...    -1.0
# 425  Job Description\nSelecting features, building ...    -1.0
# 430  Job Description\nFalcon It is seeking a Data S...    -1.0
# 431  Job Description\nData Scientist\nAre you inter...    -1.0
# 437  Description:\n\nPosition Requires a Top Secret...    -1.0
# 438  Title Data Scientist Location Remote Duration ...    -1.0
# 440  Data Scientist\n\nSonde Health, a Boston based...    -1.0
# 457  Work in a fast growing startup with unlimited ...    -1.0
# 459  We are looking for a highly motivated data sci...    -1.0
# 495  Job Overview: The Data Scientist is a key memb...    -1.0
# 496  Job Overview: The Data Scientist is a key memb...    -1.0
# 497  Job Overview: The Data Scientist is a key memb...    -1.0
# 498  Job Overview: The Data Scientist is a key memb...    -1.0
# 499  Job Overview: The Data Scientist is a key memb...    -1.0
# 500  Job Overview: The Data Scientist is a key memb...    -1.0
# 504  Job Description\nWorking at Sophinea\n\nSophin...    -1.0
# 519  Scientist / Group Lead, Cancer Biology\nLocati...    -1.0
# 524  CompuForce is seeking an experienced and highl...    -1.0
# 555  Job Description\nAs a Data Scientist, you will...    -1.0
# 568  At Kibo, we provide cloud commerce solutions i...    -1.0
# 613  DESCRIPTION\n\nGrainBridge is seeking a talent...    -1.0
# 615  Position Description\n\nSprezzatura seeks a Da...    -1.0
# 637  Job Description\nWorking at Sophinea\n\nSophin...    -1.0
# 650  Scientist / Group Lead, Cancer Biology\nLocati...    -1.0
# 656  Join our team dedicated to developing and exec...    -1.0
# 657  Overview\n\nGood people, working with good peo...    -1.0
# 660  Location: Redmond, WA\nClient: Microsoft (Un-M...    -1.0
# 664  Job Description\nClear Ridge has an exciting o...    -1.0
# 668  Job Description\nBecome a thought leader withi...    -1.0
# 669  Join a thriving company that is changing the w...    -1.0
#
#                           Company Name           Location  \
# 154           Covid-19 Search Partners      Hauppauge, NY
# 158                Radical Convergence         Reston, VA
# 230                       Encode, Inc.        Norfolk, VA
# 282                     Trovetechs Inc  San Francisco, CA
# 285                     Trovetechs Inc  San Francisco, CA
# 290                           PETADATA  San Francisco, CA
# 319                       Microagility       New York, NY
# 322           Rainmaker Resources, LLC     Cincinnati, OH
# 329                             B4Corp         Reston, VA
# 338                      Stride Search  San Francisco, CA
# 351                   Point72 Ventures      Palo Alto, CA
# 357                     Hatch Data Inc  San Francisco, CA
# 358                     Hatch Data Inc  San Francisco, CA
# 359                     Hatch Data Inc  San Francisco, CA
# 360                     Hatch Data Inc  San Francisco, CA
# 361                     Hatch Data Inc  San Francisco, CA
# 362                     Hatch Data Inc  San Francisco, CA
# 388                             HireAi  San Francisco, CA
# 389                             HireAi  San Francisco, CA
# 409                              Navio      San Mateo, CA
# 411                           Evolvinc        Burbank, CA
# 425                       Microagility       New York, NY
# 430     Falcon IT & Staffing Solutions   Fort Belvoir, VA
# 431           Rainmaker Resources, LLC     Cincinnati, OH
# 437                             B4Corp         Reston, VA
# 438                Blue Icy Water, LLC      United States
# 440                       Sonde Health         Boston, MA
# 457                      Stride Search  San Francisco, CA
# 459                     Blue Cloak LLC       Sterling, VA
# 495                     Hatch Data Inc  San Francisco, CA
# 496                     Hatch Data Inc  San Francisco, CA
# 497                     Hatch Data Inc  San Francisco, CA
# 498                     Hatch Data Inc  San Francisco, CA
# 499                     Hatch Data Inc  San Francisco, CA
# 500                     Hatch Data Inc  San Francisco, CA
# 504                           Sophinea      Chantilly, VA
# 519            Monte Rosa Therapeutics      Cambridge, MA
# 524                         CompuForce       New York, NY
# 555                             HireAi  San Francisco, CA
# 568                               Kibo   Philadelphia, PA
# 613                   GrainBridge, LLC          Omaha, NE
# 615  Sprezzatura Management Consulting     Washington, VA
# 637                           Sophinea      Chantilly, VA
# 650            Monte Rosa Therapeutics      Cambridge, MA
# 656                Berico Technologies   Fort Belvoir, VA
# 657             Kehe Food Distributors     Naperville, IL
# 660                       Pactera Edge        Redmond, WA
# 664                Clear Ridge Defense       Quantico, VA
# 668                               JKGT  San Francisco, CA
# 669                         AccessHope      Irwindale, CA
#
#              Headquarters                 Size  Founded  \
# 154                    -1                   -1       -1
# 158                    -1                   -1       -1
# 230         Manalapan, NJ    1 to 50 employees       -1
# 282      Hillsborough, NJ              Unknown       -1
# 285      Hillsborough, NJ              Unknown       -1
# 290           Fremont, CA  51 to 200 employees       -1
# 319         Princeton, NJ    1 to 50 employees       -1
# 322        Cincinnati, OH    1 to 50 employees       -1
# 329          Leesburg, VA  51 to 200 employees       -1
# 338  Westlake Village, CA    1 to 50 employees       -1
# 351                    -1                   -1       -1
# 357                    -1                   -1       -1
# 358                    -1                   -1       -1
# 359                    -1                   -1       -1
# 360                    -1                   -1       -1
# 361                    -1                   -1       -1
# 362                    -1                   -1       -1
# 388                    -1                   -1       -1
# 389                    -1                   -1       -1
# 409     Half Moon Bay, CA              Unknown       -1
# 411       Los Angeles, CA    1 to 50 employees     2005
# 425         Princeton, NJ    1 to 50 employees       -1
# 430        Washington, DC              Unknown       -1
# 431        Cincinnati, OH    1 to 50 employees       -1
# 437          Leesburg, VA  51 to 200 employees       -1
# 438           Livonia, MI    1 to 50 employees       -1
# 440            Boston, MA    1 to 50 employees       -1
# 457  Westlake Village, CA    1 to 50 employees       -1
# 459                    -1                   -1       -1
# 495                    -1                   -1       -1
# 496                    -1                   -1       -1
# 497                    -1                   -1       -1
# 498                    -1                   -1       -1
# 499                    -1                   -1       -1
# 500                    -1                   -1       -1
# 504                    -1    1 to 50 employees       -1
# 519                    -1                   -1       -1
# 524          New York, NY              Unknown       -1
# 555                    -1                   -1       -1
# 568       Marbella, Spain              Unknown       -1
# 613                    -1                   -1       -1
# 615            McLean, VA              Unknown       -1
# 637                    -1    1 to 50 employees       -1
# 650                    -1                   -1       -1
# 656                    -1                   -1       -1
# 657                    -1                   -1       -1
# 660                    -1                   -1       -1
# 664         Baltimore, MD    1 to 50 employees       -1
# 668                    -1                   -1       -1
# 669                    -1                   -1       -1
#
#            Type of ownership                          Industry  \
# 154                       -1                                -1
# 158                       -1                                -1
# 230        Company - Private                       IT Services
# 282        Company - Private                                -1
# 285        Company - Private                                -1
# 290        Company - Private                                -1
# 319        Company - Private                        Consulting
# 322        Company - Private                                -1
# 329        Company - Private                       IT Services
# 338        Company - Private                                -1
# 351                       -1                                -1
# 357                       -1                                -1
# 358                       -1                                -1
# 359                       -1                                -1
# 360                       -1                                -1
# 361                       -1                                -1
# 362                       -1                                -1
# 388                       -1                                -1
# 389                       -1                                -1
# 409                  Unknown                                -1
# 411        Company - Private                       IT Services
# 425        Company - Private                        Consulting
# 430         Company - Public                                -1
# 431        Company - Private                                -1
# 437        Company - Private                       IT Services
# 438        Company - Private                                -1
# 440  Private Practice / Firm  Health Care Services & Hospitals
# 457        Company - Private                                -1
# 459                       -1                                -1
# 495                       -1                                -1
# 496                       -1                                -1
# 497                       -1                                -1
# 498                       -1                                -1
# 499                       -1                                -1
# 500                       -1                                -1
# 504                  Unknown                                -1
# 519                       -1                                -1
# 524        Company - Private                                -1
# 555                       -1                                -1
# 568         Company - Public                                -1
# 613                       -1                                -1
# 615        Company - Private                                -1
# 637                  Unknown                                -1
# 650                       -1                                -1
# 656                       -1                                -1
# 657                       -1                                -1
# 660                       -1                                -1
# 664        Company - Private                                -1
# 668                       -1                                -1
# 669                       -1                                -1
#
#                      Sector                     Revenue Competitors
# 154                      -1                          -1          -1
# 158                      -1                          -1          -1
# 230  Information Technology     $5 to $10 million (USD)          -1
# 282                      -1    Unknown / Non-Applicable          -1
# 285                      -1    Unknown / Non-Applicable          -1
# 290                      -1    Unknown / Non-Applicable          -1
# 319       Business Services      $1 to $5 million (USD)          -1
# 322                      -1    Unknown / Non-Applicable          -1
# 329  Information Technology    Unknown / Non-Applicable          -1
# 338                      -1  Less than $1 million (USD)          -1
# 351                      -1                          -1          -1
# 357                      -1                          -1          -1
# 358                      -1                          -1          -1
# 359                      -1                          -1          -1
# 360                      -1                          -1          -1
# 361                      -1                          -1          -1
# 362                      -1                          -1          -1
# 388                      -1                          -1          -1
# 389                      -1                          -1          -1
# 409                      -1    Unknown / Non-Applicable          -1
# 411  Information Technology    Unknown / Non-Applicable          -1
# 425       Business Services      $1 to $5 million (USD)          -1
# 430                      -1    Unknown / Non-Applicable          -1
# 431                      -1    Unknown / Non-Applicable          -1
# 437  Information Technology    Unknown / Non-Applicable          -1
# 438                      -1    Unknown / Non-Applicable          -1
# 440             Health Care  Less than $1 million (USD)          -1
# 457                      -1  Less than $1 million (USD)          -1
# 459                      -1                          -1          -1
# 495                      -1                          -1          -1
# 496                      -1                          -1          -1
# 497                      -1                          -1          -1
# 498                      -1                          -1          -1
# 499                      -1                          -1          -1
# 500                      -1                          -1          -1
# 504                      -1    Unknown / Non-Applicable          -1
# 519                      -1                          -1          -1
# 524                      -1    Unknown / Non-Applicable          -1
# 555                      -1                          -1          -1
# 568                      -1    Unknown / Non-Applicable          -1
# 613                      -1                          -1          -1
# 615                      -1    Unknown / Non-Applicable          -1
# 637                      -1    Unknown / Non-Applicable          -1
# 650                      -1                          -1          -1
# 656                      -1                          -1          -1
# 657                      -1                          -1          -1
# 660                      -1                          -1          -1
# 664                      -1    Unknown / Non-Applicable          -1
# 668                      -1                          -1          -1
# 669                      -1                          -1          -1

# %%
# this reveals that -1 seems to be the default value for missing data in the rating column as well as others

# %%
# for the ratings, these -1.0 values are changed to empty cells so that their values don't affect calculations such as averages

df['Rating'] = df['Rating'].replace(-1.0, np.nan)

# %%
# for the other columns, the -1 values are replaced with blank cells 

df = df.replace('-1', '')

# %% [markdown]
# ## Turning the size column into numerical

# %%
# showing all the different values in the size column to see if there are any non-standard ones

df['Size'].unique()
# Out:
# array(['1001 to 5000 employees', '5001 to 10000 employees',
#        '501 to 1000 employees', '51 to 200 employees', '10000+ employees',
#        '201 to 500 employees', '1 to 50 employees', '', 'Unknown'],
#       dtype=object)

# %%
# creating a new column with the approximate number of employees being in the middle of the range

df['approx_employees'] = df['Size'].replace({
                                '1 to 50 employees':25, 
                                '51 to 200 employees':125,
                                '201 to 500 employees':350,
                                '501 to 1000 employees':750,
                                '1001 to 5000 employees':2500,
                                '5001 to 10000 employees':7500,
                                '10000+ employees':15000,
                                'Unknown':pd.NA,
                                '':pd.NA})

df['approx_employees'] = df['approx_employees'].astype('Int64')

#reordering columns to put size and approx employees together

df = df[['Job Title', 'level_keywords', 'role_keywords', 'Salary Estimate', 'min_salary_est($K)', 'max_salary_est($K)', 'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'approx_employees', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors']]
df.head()
# Out:
#            Job Title level_keywords    role_keywords  \
# 0  Sr Data Scientist             sr  data, scientist
# 1     Data Scientist           None  data, scientist
# 2     Data Scientist           None  data, scientist
# 3     Data Scientist           None  data, scientist
# 4     Data Scientist           None  data, scientist
#
#                 Salary Estimate  min_salary_est($K)  max_salary_est($K)  \
# 0  $137K-$171K (Glassdoor est.)                 137                 171
# 1  $137K-$171K (Glassdoor est.)                 137                 171
# 2  $137K-$171K (Glassdoor est.)                 137                 171
# 3  $137K-$171K (Glassdoor est.)                 137                 171
# 4  $137K-$171K (Glassdoor est.)                 137                 171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9   New York, NY            New York, NY
#
#                       Size  approx_employees  Founded  \
# 0   1001 to 5000 employees              2500     1993
# 1  5001 to 10000 employees              7500     1968
# 2   1001 to 5000 employees              2500     1981
# 3    501 to 1000 employees               750     2000
# 4      51 to 200 employees               125     1998
#
#          Type of ownership                               Industry  \
# 0   Nonprofit Organization                     Insurance Carriers
# 1         Company - Public                 Research & Development
# 2  Private Practice / Firm                             Consulting
# 3         Company - Public  Electrical & Electronic Manufacturing
# 4        Company - Private                Advertising & Marketing
#
#               Sector                     Revenue  \
# 0          Insurance    Unknown / Non-Applicable
# 1  Business Services      $1 to $2 billion (USD)
# 2  Business Services  $100 to $500 million (USD)
# 3      Manufacturing  $100 to $500 million (USD)
# 4  Business Services    Unknown / Non-Applicable
#
#                                          Competitors
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1
# 2
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee

# %% [markdown]
# ## Looking for issues with the locations

# %%
# displaying the unique locations to scan for any unusual entries

sorted(df['Location'].unique())
# Out:
# ['Adelphi, MD',
#  'Akron, OH',
#  'Alexandria, VA',
#  'Alpharetta, GA',
#  'Ann Arbor, MI',
#  'Annapolis Junction, MD',
#  'Appleton, WI',
#  'Arlington, VA',
#  'Ashburn, VA',
#  'Atlanta, GA',
#  'Aurora, CO',
#  'Austin, TX',
#  'Baltimore, MD',
#  'Beavercreek, OH',
#  'Bedford, MA',
#  'Bellevue, WA',
#  'Bethesda, MD',
#  'Birmingham, AL',
#  'Blue Bell, PA',
#  'Boston, MA',
#  'Bothell, WA',
#  'Boulder, CO',
#  'Bridgeport, WV',
#  'Brisbane, CA',
#  'Brooklyn, NY',
#  'Burbank, CA',
#  'Burlingame, CA',
#  'California',
#  'Cambridge, MA',
#  'Carmel, IN',
#  'Carpinteria, CA',
#  'Carson, CA',
#  'Cedar Rapids, IA',
#  'Champaign, IL',
#  'Chandler, AZ',
#  'Chantilly, VA',
#  'Charlotte, NC',
#  'Chicago, IL',
#  'Cincinnati, OH',
#  'Cleveland, OH',
#  'Collegeville, PA',
#  'Colorado Springs, CO',
#  'Columbia, MD',
#  'Columbia, MO',
#  'Columbia, SC',
#  'Concord, CA',
#  'Coral Gables, FL',
#  'Culver City, CA',
#  'Cupertino, CA',
#  'Dallas, TX',
#  'Danvers, MA',
#  'Dayton, OH',
#  'Dearborn, MI',
#  'Denver, CO',
#  'Durham, NC',
#  'Edison, NJ',
#  'Emeryville, CA',
#  'Ewing, NJ',
#  'Fairfax, VA',
#  'Falls Church, VA',
#  'Fort Belvoir, VA',
#  'Fort Lee, NJ',
#  'Fort Meade, MD',
#  'Fort Sam Houston, TX',
#  'Fort Wayne, IN',
#  'Fort Worth, TX',
#  'Foster City, CA',
#  'Frederick, MD',
#  'Fremont, CA',
#  'Gahanna, OH',
#  'Gaithersburg, MD',
#  'Germantown, MD',
#  'Hamilton, NJ',
#  'Hampton, VA',
#  'Harrisburg, PA',
#  'Hartford, CT',
#  'Hauppauge, NY',
#  'Herndon, VA',
#  'Hill AFB, UT',
#  'Hoboken, NJ',
#  'Holyoke, MA',
#  'Houston, TX',
#  'Huntsville, AL',
#  'Indianapolis, IN',
#  'Ipswich, MA',
#  'Irvine, CA',
#  'Irwindale, CA',
#  'Jersey City, NJ',
#  'Kansas City, MO',
#  'Kent, OH',
#  'Lake Oswego, OR',
#  'Laurel, MD',
#  'Lebanon, IN',
#  'Lehi, UT',
#  'Lexington Park, MD',
#  'Lexington, MA',
#  'Lincoln, NE',
#  'Linthicum Heights, MD',
#  'Livermore, CA',
#  'Lombard, IL',
#  'Longmont, CO',
#  'Madison, WI',
#  'Manchester, NH',
#  'Maple Plain, MN',
#  'Maryland Heights, MO',
#  'McLean, VA',
#  'Melbourne, FL',
#  'Memphis, TN',
#  'Menlo Park, CA',
#  'Merrifield, VA',
#  'Minneapolis, MN',
#  'Monroe, WI',
#  'Monterey, CA',
#  'Mountain View, CA',
#  'Naperville, IL',
#  'Nashville, TN',
#  'New Bedford, MA',
#  'New Jersey',
#  'New Orleans, LA',
#  'New York, NY',
#  'Newton, MA',
#  'Norfolk, VA',
#  'Northbrook, IL',
#  'Norwell, MA',
#  'Oak Ridge, TN',
#  'Oakland, CA',
#  'Oakville, CA',
#  'Oklahoma City, OK',
#  'Omaha, NE',
#  'Open Fork, VA',
#  'Orange, CA',
#  'Orlando, FL',
#  'Oshkosh, WI',
#  'Overland Park, KS',
#  'Oxnard, CA',
#  'Palo Alto, CA',
#  'Patuxent, Anne Arundel, MD',
#  'Peoria, IL',
#  'Philadelphia, PA',
#  'Phoenix, AZ',
#  'Piscataway, NJ',
#  'Pittsburgh, PA',
#  'Plano, TX',
#  'Pleasanton, CA',
#  'Portland, OR',
#  'Portsmouth, NH',
#  'Quantico, VA',
#  'Raleigh, NC',
#  'Rancho Cucamonga, CA',
#  'Redmond, WA',
#  'Redwood City, CA',
#  'Remote',
#  'Reston, VA',
#  'Richland, WA',
#  'Richmond, VA',
#  'Rockville, MD',
#  'Sacramento, CA',
#  'Saint Louis, MO',
#  'San Antonio, TX',
#  'San Carlos, CA',
#  'San Clemente, CA',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'San Mateo, CA',
#  'San Ramon, CA',
#  'Santa Barbara, CA',
#  'Santa Clara, CA',
#  'Santa Cruz, CA',
#  'Santa Monica, CA',
#  'Schaumburg, IL',
#  'Scotts Valley, CA',
#  'Seattle, WA',
#  'Sheboygan, WI',
#  'Silver Spring, MD',
#  'Simi Valley, CA',
#  'Smithfield, RI',
#  'South San Francisco, CA',
#  'Southfield, MI',
#  'Spartanburg, SC',
#  'Springfield, VA',
#  'Sterling, VA',
#  'Sunnyvale, CA',
#  'Texas',
#  'The Woodlands, TX',
#  'Thousand Oaks, CA',
#  'Timonium, MD',
#  'Trumbull, CT',
#  'Tulsa, OK',
#  'United States',
#  'Utah',
#  'Vicksburg, MS',
#  'Vienna, VA',
#  'Waltham, MA',
#  'Washington, DC',
#  'Washington, VA',
#  'Wellesley, MA',
#  'West Chester, PA',
#  'West Grove, PA',
#  'Wilmington, DE',
#  'Winston-Salem, NC',
#  'Winter Park, FL',
#  'Winters, TX',
#  'Woburn, MA',
#  'Woodbridge, NJ',
#  'Woodlawn, MD',
#  'Yakima, WA']

# %%
# no duplicates, all have same format except 'Utah' and 'United States' but insufficient data to improve these

# %% [markdown]
# ## Looking for issues with the types of ownership

# %%
# displaying the unique types of ownership to scan for any unusual entries

df['Type of ownership'].unique()
# Out:
# array(['Nonprofit Organization', 'Company - Public',
#        'Private Practice / Firm', 'Company - Private', 'Government',
#        'Subsidiary or Business Segment', 'Other Organization', '',
#        'Hospital', 'Self-employed', 'College / University', 'Contract'],
#       dtype=object)

# %%
# replacing unknown with empty cells, otherwise no issues

df['Type of ownership'] = df['Type of ownership'].replace('Unknown', '')

# %% [markdown]
# ## Looking at issues with industry and sector

# %%
# displaying the unique industries to scan for any unusual entries

sorted(df['Industry'].unique())
# Out:
# ['',
#  'Accounting',
#  'Advertising & Marketing',
#  'Aerospace & Defense',
#  'Architectural & Engineering Services',
#  'Banks & Credit Unions',
#  'Biotech & Pharmaceuticals',
#  'Cable, Internet & Telephone Providers',
#  'Chemical Manufacturing',
#  'Colleges & Universities',
#  'Computer Hardware & Software',
#  'Construction',
#  'Consulting',
#  'Consumer Electronics & Appliances Stores',
#  'Consumer Products Manufacturing',
#  'Department, Clothing, & Shoe Stores',
#  'Electrical & Electronic Manufacturing',
#  'Energy',
#  'Enterprise Software & Network Solutions',
#  'Express Delivery Services',
#  'Farm Support Services',
#  'Federal Agencies',
#  'Financial Transaction Processing',
#  'Food & Beverage Manufacturing',
#  'Food & Beverage Stores',
#  'Health Care Services & Hospitals',
#  'Health, Beauty, & Fitness',
#  'Hotels, Motels, & Resorts',
#  'IT Services',
#  'Industrial Manufacturing',
#  'Insurance Agencies & Brokerages',
#  'Insurance Carriers',
#  'Internet',
#  'Investment Banking & Asset Management',
#  'Lending',
#  'Logistics & Supply Chain',
#  'Miscellaneous Manufacturing',
#  'News Outlet',
#  'Oil & Gas Services',
#  'Other Retail Stores',
#  'Publishing',
#  'Rail',
#  'Real Estate',
#  'Research & Development',
#  'Shipping',
#  'Social Assistance',
#  'Staffing & Outsourcing',
#  'State & Regional Agencies',
#  'Telecommunications Manufacturing',
#  'Telecommunications Services',
#  'Timber Operations',
#  'Transportation Equipment Manufacturing',
#  'Transportation Management',
#  'Travel Agencies',
#  'Utilities',
#  'Venture Capital & Private Equity',
#  'Video Games',
#  'Wholesale']

# %%
# displaying the unique sectors to scan for any unusual entries

sorted(df['Sector'].unique())
# Out:
# ['',
#  'Accounting & Legal',
#  'Aerospace & Defense',
#  'Agriculture & Forestry',
#  'Biotech & Pharmaceuticals',
#  'Business Services',
#  'Construction, Repair & Maintenance',
#  'Consumer Services',
#  'Education',
#  'Finance',
#  'Government',
#  'Health Care',
#  'Information Technology',
#  'Insurance',
#  'Manufacturing',
#  'Media',
#  'Non-Profit',
#  'Oil, Gas, Energy & Utilities',
#  'Real Estate',
#  'Retail',
#  'Telecommunications',
#  'Transportation & Logistics',
#  'Travel & Tourism']

# %%
# no issues

# %% [markdown]
# ## Converting the revenue to numerical

# %%
# displaying the unique revenue ranges to see if there are any non-standard ones

df['Revenue'].unique()
# Out:
# array(['Unknown / Non-Applicable', '$1 to $2 billion (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$500 million to $1 billion (USD)',
#        '$5 to $10 billion (USD)', '$10 to $25 million (USD)',
#        '$25 to $50 million (USD)', '$50 to $100 million (USD)',
#        '$1 to $5 million (USD)', '$5 to $10 million (USD)',
#        'Less than $1 million (USD)', ''], dtype=object)

# %%
# creating a new column with the approximate revenue being in the middle of the range, replacing empty or unknown values with NaN

df['approx_revenue($Mil)'] = df['Revenue'].replace({
                                'Less than $1 million (USD)':0.5, 
                                '$1 to $5 million (USD)':2.5,
                                '$5 to $10 million (USD)':7.5,
                                '$10 to $25 million (USD)':17.5,
                                '$25 to $50 million (USD)':37.5,
                                '$50 to $100 million (USD)':75,
                                '$100 to $500 million (USD)':300,
                                '$500 million to $1 billion (USD)':750,
                                '$1 to $2 billion (USD)':1500,
                                '$2 to $5 billion (USD)':3750,
                                '$5 to $10 billion (USD)':7500,
                                '$10+ billion (USD)':15000,
                                'Unknown / Non-Applicable':pd.NA,
                                '':pd.NA})

df['approx_revenue($Mil)'] = df['approx_revenue($Mil)'].astype('Float64')

# reordeing the columns to put revenue and approx revenue together

df = df[['Job Title', 'level_keywords', 'role_keywords', 'Salary Estimate', 'min_salary_est($K)', 'max_salary_est($K)', 'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'approx_employees', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'approx_revenue($Mil)', 'Competitors']]
df.head()
# Out:
#            Job Title level_keywords    role_keywords  \
# 0  Sr Data Scientist             sr  data, scientist
# 1     Data Scientist           None  data, scientist
# 2     Data Scientist           None  data, scientist
# 3     Data Scientist           None  data, scientist
# 4     Data Scientist           None  data, scientist
#
#                 Salary Estimate  min_salary_est($K)  max_salary_est($K)  \
# 0  $137K-$171K (Glassdoor est.)                 137                 171
# 1  $137K-$171K (Glassdoor est.)                 137                 171
# 2  $137K-$171K (Glassdoor est.)                 137                 171
# 3  $137K-$171K (Glassdoor est.)                 137                 171
# 4  $137K-$171K (Glassdoor est.)                 137                 171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9   New York, NY            New York, NY
#
#                       Size  approx_employees  Founded  \
# 0   1001 to 5000 employees              2500     1993
# 1  5001 to 10000 employees              7500     1968
# 2   1001 to 5000 employees              2500     1981
# 3    501 to 1000 employees               750     2000
# 4      51 to 200 employees               125     1998
#
#          Type of ownership                               Industry  \
# 0   Nonprofit Organization                     Insurance Carriers
# 1         Company - Public                 Research & Development
# 2  Private Practice / Firm                             Consulting
# 3         Company - Public  Electrical & Electronic Manufacturing
# 4        Company - Private                Advertising & Marketing
#
#               Sector                     Revenue  approx_revenue($Mil)  \
# 0          Insurance    Unknown / Non-Applicable                  <NA>
# 1  Business Services      $1 to $2 billion (USD)                1500.0
# 2  Business Services  $100 to $500 million (USD)                 300.0
# 3      Manufacturing  $100 to $500 million (USD)                 300.0
# 4  Business Services    Unknown / Non-Applicable                  <NA>
#
#                                          Competitors
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1
# 2
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee

# %% [markdown]
# ## Looking for null values

# %%
df.isna().sum()
# Out:
# Job Title                 0
# level_keywords          557
# role_keywords             0
# Salary Estimate           0
# min_salary_est($K)        0
# max_salary_est($K)        0
# Job Description           0
# Rating                   50
# Company Name              0
# Location                  0
# Headquarters              0
# Size                      0
# approx_employees         17
# Founded                   0
# Type of ownership         0
# Industry                  0
# Sector                    0
# Revenue                   0
# approx_revenue($Mil)    240
# Competitors               0
# dtype: int64

# %%
# NaN values only appear in the created columns and the rating column which isn't an issue

# %%
(df=='').sum()
# Out:
# Job Title                 0
# level_keywords            0
# role_keywords             0
# Salary Estimate           0
# min_salary_est($K)        0
# max_salary_est($K)        0
# Job Description           0
# Rating                    0
# Company Name              0
# Location                  0
# Headquarters             31
# Size                     27
# approx_employees         27
# Founded                 118
# Type of ownership        31
# Industry                 71
# Sector                   71
# Revenue                  27
# approx_revenue($Mil)      0
# Competitors             501
# dtype: int64

# %%
# several columns with blank values but insufficient data to populate them

# %% [markdown]
# ## Dataset is now clean and ready to be used for analysis
